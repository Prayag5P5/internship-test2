# %%
import pandas as pd

# %%
file = pd.read_csv("main.csv")

# %%
file.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
file.tail()
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 11             0              0                     0  ...          17
# ...

# %%
solution = file.groupby(['Team'])[['Yellow Cards','Red Cards']].sum()

# %%
solution.head()
# Out:
#                 Yellow Cards  Red Cards
# Team
# Croatia                    9          0
# Czech Republic             7          0
# Denmark                    4          0
# England                    5          0
# France                     6          0

# %%
solution = solution.sort_values(by=['Yellow Cards'], ascending = False)

# %%
solution = solution.sort_values(by=['Red Cards'], ascending = False)

# %%
solution.head()
# Out:
#                      Yellow Cards  Red Cards
# Team
# Greece                          9          1
# Poland                          7          1
# Republic of Ireland             6          1
# Italy                          16          0
# Portugal                       12          0

# %%
solution.tail()
# Out:
#              Yellow Cards  Red Cards
# Team
# England                 5          0
# Netherlands             5          0
# Ukraine                 5          0
# Denmark                 4          0
# Germany                 4          0

# %%
solution.to_csv('output_3.csv')
